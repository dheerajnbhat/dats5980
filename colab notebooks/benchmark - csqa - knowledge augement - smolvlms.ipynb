# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cp "/content/drive/MyDrive/DATS 5980/knowledge_augment_csqa_val.pkl" /content/

# %%
# %cd /content/
# Out:
# /content

# %%
import os
import json
import torch
from PIL import Image
from transformers import AutoProcessor, AutoModelForVision2Seq
from transformers.image_utils import load_image

# %%
import random
import numpy as np
import torch

def set_seed(seed: int = 42):
    """
    Set random seed for reproducibility across Python, NumPy, and PyTorch.
    """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    # For deterministic behavior (slower but fully reproducible)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {DEVICE}")
# Out:
# Using device: cuda

# %%
import pickle

dataset_path = "/content/drive/MyDrive/DATS 5980/knowledge_augment_csqa_val.pkl"

with open(dataset_path, "rb") as fp:
    csqa_dataset = pickle.load(fp)

len(csqa_dataset)
# Out:
# 1221

# %%
csqa_dataset[0]
# Out:
# {'id': '1afa02df02c908a558b4036e80242fac',
#  'question': 'A revolving door is convenient for two direction travel, but it also serves as a security measure at a what?',
#  'question_concept': 'revolving door',
#  'choices': {'label': ['A', 'B', 'C', 'D', 'E'],
#   'text': ['bank', 'library', 'department store', 'mall', 'new york']},
#  'answerKey': 'A',
#  'correct_answer': 'bank',
#  'ranked_choices': [('bank', 0.14749882221221924),
#   ('mall', 0.1399820104241371),
#   ('department store', 0.12084722220897674),
#   ('library', 0.061140642315149304),
#   ('new york', 0.0514893963932991)],
#  'debug': {'sim_question_choice': [0.12540851533412933,
#    0.019575992599129677,
#    0.051216669380664825,
#    0.039423618465662,
#    0.035584140568971634],
#   'sim_choice_conceptnet': [0.16222569346427917,
#    0.08885040879249573,
#    0.1672675907611847,
#    0.20702093839645386,
#    0.06209290027618408],
#   'scores': [0.14749882221221924,
#    0.061140642315149304,
#    0.12084722220897674,
#    0.1399820104241371,
#    0.0514893963932991],
#   'cn_relations_for_ranked_choices': {'bank': ['revolving door is AtLocation bank'],
#    'mall': ['revolving door is AtLocation mall'],
#    'department store': ['revolving door is AtLocation department store'],
#    'library': [],
#    'new york': []}}}

# %%
# model_name = "HuggingFaceTB/SmolVLM-256M-Instruct"
# model_name = "HuggingFaceTB/SmolVLM-500M-Instruct"
model_name = "HuggingFaceTB/SmolVLM-Instruct"

# model_name = "HuggingFaceTB/SmolVLM-256M-Base"

# %% [markdown]
# # Single Prediction

# %%
# Initialize processor and model
processor = AutoProcessor.from_pretrained(model_name)
model = AutoModelForVision2Seq.from_pretrained(
    model_name,
    torch_dtype=torch.bfloat16,
    # _attn_implementation="flash_attention_2" if DEVICE == "cuda" else "eager",
).to(DEVICE)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# processor_config.json:   0%|          | 0.00/68.0 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/429 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/486 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/modeling_auto.py:2284: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/1.02G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/136 [00:00<?, ?B/s]

# %%
def get_prediction(data_point, coco_dir, split):
    question = data_point['question']

    image_path = get_coco_path(split, data_point['image_id'], coco_dir)
    # image = load_image(image_path)
    image = Image.open(image_path).convert("RGB")

    # Create input messages
    messages = [
        {
            "role": "user",
            "content": [
                {"type": "image"},
                {"type": "text", "text": question}
            ]
        },
    ]

    # Prepare inputs
    prompt = processor.apply_chat_template(messages, add_generation_prompt=True)
    inputs = processor(text=prompt, images=[image], return_tensors="pt")
    inputs = inputs.to(DEVICE)

    # Generate outputs
    generated_ids = model.generate(**inputs, max_new_tokens=500)
    generated_texts = processor.batch_decode(
        generated_ids,
        skip_special_tokens=True,
    )
    return data_point, generated_texts[0]

# %%
predictions = []
for idx, data_point in enumerate(val_aokvqa_dataset):
    data_point, pred = get_prediction(data_point, coco_filtered_dir, 'val')
    print(idx, end=",")
    predictions.append((data_point, pred))
    break
# Out:
# 0,

# %%
data_point, pred
# Out:
# ({'split': 'val',
#   'image_id': 461751,
#   'question_id': '22jbM6gDxdaMaunuzgrsBB',
#   'question': "What is in the motorcyclist's mouth?",
#   'choices': ['toothpick', 'food', 'popsicle stick', 'cigarette'],
#   'correct_choice_idx': 3,
#   'direct_answers': ['cigarette',
#    'cigarette',
#    'cigarette',
#    'cigarette',
#    'cigarette',
#    'cigarette',
#    'cigarette',
#    'cigarette',
#    'cigarette',
#    'cigarette'],
#   'difficult_direct_answer': False,
#   'rationales': ["He's smoking while riding.",
#    'The motorcyclist has a lit cigarette in his mouth while he rides on the street.',
#    'The man is smoking.']},
#  "User:\n\n\n\n\nWhat is in the motorcyclist's mouth?\nAssistant: The motorcyclist is wearing a mouth guard.")

# %% [markdown]
# # Batch Prediction

# %%
# model_name = "HuggingFaceTB/SmolVLM-256M-Instruct"

# Initialize processor and model
processor = AutoProcessor.from_pretrained(model_name)

# Force left padding for decoder-only generation
if hasattr(processor, "tokenizer"):
    processor.tokenizer.padding_side = "left"
    if processor.tokenizer.pad_token is None:
        processor.tokenizer.pad_token = processor.tokenizer.eos_token

model = AutoModelForVision2Seq.from_pretrained(
    model_name,
    torch_dtype=torch.bfloat16,
    # _attn_implementation="flash_attention_2" if DEVICE == "cuda" else "eager",
).to(DEVICE)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# processor_config.json:   0%|          | 0.00/68.0 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/429 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/486 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/92.0 [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/modeling_auto.py:2284: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/4.49G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/136 [00:00<?, ?B/s]

# %%
prompt = """
Question: {question}
Choices: {choices}

These are the choices ranked using semantic ranker and some of the facts related to it:
{knowledge_context}

Use proper reasoning and facts provided.
Give only the single correct answer. Do not provide any reasoning, explanation, or extra text.
Answer (just one choice):
""".strip()

def get_batch_predictions(data_points):
    """
    Generate predictions for a batch of data points.

    Args:
        data_points (list): List of data point dicts.

    Returns:
        List of (data_point, prediction) tuples.
    """
    # Prepare images and questions
    images = []
    batch_messages = []
    for data_point in data_points:
        question = data_point['question']
        choices = data_point['choices']['text']

        ranked_choices = data_point['ranked_choices']
        knowledge_context = ""
        for c, s in ranked_choices:
            relation_text = data_point["debug"]["cn_relations_for_ranked_choices"][c]
            if relation_text:
                knowledge_context += f"Choice: {c}\n" + " ".join(relation_text) + ".\n"
            # else:
            #     knowledge_context += f"Choice {c} is not related to this question.\n"

        # knowledge_context = data_point["knowledge_context"]

        mcq_question = prompt.format(question=question, choices=choices, knowledge_context=knowledge_context).strip()

        messages = [
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": mcq_question}
                ]
            }
        ]
        batch_messages.append(messages)

    # Prepare prompts for each message
    batch_prompts = [processor.apply_chat_template(msg, add_generation_prompt=True) for msg in batch_messages]

    # Prepare inputs for the batch
    batch_inputs = processor(
        text=batch_prompts,
        return_tensors="pt",
        padding=True
    )
    batch_inputs = batch_inputs.to(DEVICE)

    # Generate outputs
    batch_generated_ids = model.generate(**batch_inputs)
    batch_generated_texts = processor.batch_decode(
        batch_generated_ids,
        skip_special_tokens=True,
    )

    return list(zip(data_points, batch_generated_texts))

# %%
def run_batch_predictions(csqa_dataset, batch_size):
    predictions = []
    for i in range(0, len(csqa_dataset), batch_size):
        batch = csqa_dataset[i:i+batch_size]
        batch_results = get_batch_predictions(batch)
        for item in batch_results:
            predictions.append(item)
        print(f"Batch number: ({(i+1)//batch_size} / {len(csqa_dataset)/batch_size}). Progress: {(i+1) / len(csqa_dataset)*100:.2f}%")
    return predictions

# %%
batch_size = 6
# dataset = csqa_dataset[: 6]
dataset = csqa_dataset

predictions = run_batch_predictions(dataset, batch_size)
# Out:
# Batch number: (0 / 203.5). Progress: 0.08%
# Batch number: (1 / 203.5). Progress: 0.57%
# Batch number: (2 / 203.5). Progress: 1.06%
# Batch number: (3 / 203.5). Progress: 1.56%
# Batch number: (4 / 203.5). Progress: 2.05%
# Batch number: (5 / 203.5). Progress: 2.54%
# Batch number: (6 / 203.5). Progress: 3.03%
# Batch number: (7 / 203.5). Progress: 3.52%
# Batch number: (8 / 203.5). Progress: 4.01%
# Batch number: (9 / 203.5). Progress: 4.50%
# Batch number: (10 / 203.5). Progress: 5.00%
# Batch number: (11 / 203.5). Progress: 5.49%
# Batch number: (12 / 203.5). Progress: 5.98%
# Batch number: (13 / 203.5). Progress: 6.47%
# Batch number: (14 / 203.5). Progress: 6.96%
# Batch number: (15 / 203.5). Progress: 7.45%
# Batch number: (16 / 203.5). Progress: 7.94%
# Batch number: (17 / 203.5). Progress: 8.44%
# Batch number: (18 / 203.5). Progress: 8.93%
# Batch number: (19 / 203.5). Progress: 9.42%
# Batch number: (20 / 203.5). Progress: 9.91%
# Batch number: (21 / 203.5). Progress: 10.40%
# Batch number: (22 / 203.5). Progress: 10.89%
# Batch number: (23 / 203.5). Progress: 11.38%
# Batch number: (24 / 203.5). Progress: 11.88%
# Batch number: (25 / 203.5). Progress: 12.37%
# Batch number: (26 / 203.5). Progress: 12.86%
# Batch number: (27 / 203.5). Progress: 13.35%
# Batch number: (28 / 203.5). Progress: 13.84%
# Batch number: (29 / 203.5). Progress: 14.33%
# Batch number: (30 / 203.5). Progress: 14.82%
# Batch number: (31 / 203.5). Progress: 15.32%
# Batch number: (32 / 203.5). Progress: 15.81%
# Batch number: (33 / 203.5). Progress: 16.30%
# Batch number: (34 / 203.5). Progress: 16.79%
# Batch number: (35 / 203.5). Progress: 17.28%
# Batch number: (36 / 203.5). Progress: 17.77%
# Batch number: (37 / 203.5). Progress: 18.26%
# Batch number: (38 / 203.5). Progress: 18.76%
# Batch number: (39 / 203.5). Progress: 19.25%
# Batch number: (40 / 203.5). Progress: 19.74%
# Batch number: (41 / 203.5). Progress: 20.23%
# Batch number: (42 / 203.5). Progress: 20.72%
# Batch number: (43 / 203.5). Progress: 21.21%
# Batch number: (44 / 203.5). Progress: 21.70%
# Batch number: (45 / 203.5). Progress: 22.19%
# Batch number: (46 / 203.5). Progress: 22.69%
# Batch number: (47 / 203.5). Progress: 23.18%
# Batch number: (48 / 203.5). Progress: 23.67%
# Batch number: (49 / 203.5). Progress: 24.16%
# Batch number: (50 / 203.5). Progress: 24.65%
# Batch number: (51 / 203.5). Progress: 25.14%
# Batch number: (52 / 203.5). Progress: 25.63%
# Batch number: (53 / 203.5). Progress: 26.13%
# Batch number: (54 / 203.5). Progress: 26.62%
# Batch number: (55 / 203.5). Progress: 27.11%
# Batch number: (56 / 203.5). Progress: 27.60%
# Batch number: (57 / 203.5). Progress: 28.09%
# Batch number: (58 / 203.5). Progress: 28.58%
# Batch number: (59 / 203.5). Progress: 29.07%
# Batch number: (60 / 203.5). Progress: 29.57%
# Batch number: (61 / 203.5). Progress: 30.06%
# Batch number: (62 / 203.5). Progress: 30.55%
# Batch number: (63 / 203.5). Progress: 31.04%
# Batch number: (64 / 203.5). Progress: 31.53%
# Batch number: (65 / 203.5). Progress: 32.02%
# Batch number: (66 / 203.5). Progress: 32.51%
# Batch number: (67 / 203.5). Progress: 33.01%
# Batch number: (68 / 203.5). Progress: 33.50%
# Batch number: (69 / 203.5). Progress: 33.99%
# Batch number: (70 / 203.5). Progress: 34.48%
# Batch number: (71 / 203.5). Progress: 34.97%
# Batch number: (72 / 203.5). Progress: 35.46%
# Batch number: (73 / 203.5). Progress: 35.95%
# Batch number: (74 / 203.5). Progress: 36.45%
# Batch number: (75 / 203.5). Progress: 36.94%
# Batch number: (76 / 203.5). Progress: 37.43%
# Batch number: (77 / 203.5). Progress: 37.92%
# Batch number: (78 / 203.5). Progress: 38.41%
# Batch number: (79 / 203.5). Progress: 38.90%
# Batch number: (80 / 203.5). Progress: 39.39%
# Batch number: (81 / 203.5). Progress: 39.89%
# Batch number: (82 / 203.5). Progress: 40.38%
# Batch number: (83 / 203.5). Progress: 40.87%
# Batch number: (84 / 203.5). Progress: 41.36%
# Batch number: (85 / 203.5). Progress: 41.85%
# Batch number: (86 / 203.5). Progress: 42.34%
# Batch number: (87 / 203.5). Progress: 42.83%
# Batch number: (88 / 203.5). Progress: 43.33%
# Batch number: (89 / 203.5). Progress: 43.82%
# Batch number: (90 / 203.5). Progress: 44.31%
# Batch number: (91 / 203.5). Progress: 44.80%
# Batch number: (92 / 203.5). Progress: 45.29%
# Batch number: (93 / 203.5). Progress: 45.78%
# Batch number: (94 / 203.5). Progress: 46.27%
# Batch number: (95 / 203.5). Progress: 46.76%
# Batch number: (96 / 203.5). Progress: 47.26%
# Batch number: (97 / 203.5). Progress: 47.75%
# Batch number: (98 / 203.5). Progress: 48.24%
# Batch number: (99 / 203.5). Progress: 48.73%
# Batch number: (100 / 203.5). Progress: 49.22%
# Batch number: (101 / 203.5). Progress: 49.71%
# Batch number: (102 / 203.5). Progress: 50.20%
# Batch number: (103 / 203.5). Progress: 50.70%
# Batch number: (104 / 203.5). Progress: 51.19%
# Batch number: (105 / 203.5). Progress: 51.68%
# Batch number: (106 / 203.5). Progress: 52.17%
# Batch number: (107 / 203.5). Progress: 52.66%
# Batch number: (108 / 203.5). Progress: 53.15%
# Batch number: (109 / 203.5). Progress: 53.64%
# Batch number: (110 / 203.5). Progress: 54.14%
# Batch number: (111 / 203.5). Progress: 54.63%
# Batch number: (112 / 203.5). Progress: 55.12%
# Batch number: (113 / 203.5). Progress: 55.61%
# Batch number: (114 / 203.5). Progress: 56.10%
# Batch number: (115 / 203.5). Progress: 56.59%
# Batch number: (116 / 203.5). Progress: 57.08%
# Batch number: (117 / 203.5). Progress: 57.58%
# Batch number: (118 / 203.5). Progress: 58.07%
# Batch number: (119 / 203.5). Progress: 58.56%
# Batch number: (120 / 203.5). Progress: 59.05%
# Batch number: (121 / 203.5). Progress: 59.54%
# Batch number: (122 / 203.5). Progress: 60.03%
# Batch number: (123 / 203.5). Progress: 60.52%
# Batch number: (124 / 203.5). Progress: 61.02%
# Batch number: (125 / 203.5). Progress: 61.51%
# Batch number: (126 / 203.5). Progress: 62.00%
# Batch number: (127 / 203.5). Progress: 62.49%
# Batch number: (128 / 203.5). Progress: 62.98%
# Batch number: (129 / 203.5). Progress: 63.47%
# Batch number: (130 / 203.5). Progress: 63.96%
# Batch number: (131 / 203.5). Progress: 64.46%
# Batch number: (132 / 203.5). Progress: 64.95%
# Batch number: (133 / 203.5). Progress: 65.44%
# Batch number: (134 / 203.5). Progress: 65.93%
# Batch number: (135 / 203.5). Progress: 66.42%
# Batch number: (136 / 203.5). Progress: 66.91%
# Batch number: (137 / 203.5). Progress: 67.40%
# Batch number: (138 / 203.5). Progress: 67.90%
# Batch number: (139 / 203.5). Progress: 68.39%
# Batch number: (140 / 203.5). Progress: 68.88%
# Batch number: (141 / 203.5). Progress: 69.37%
# Batch number: (142 / 203.5). Progress: 69.86%
# Batch number: (143 / 203.5). Progress: 70.35%
# Batch number: (144 / 203.5). Progress: 70.84%
# Batch number: (145 / 203.5). Progress: 71.33%
# Batch number: (146 / 203.5). Progress: 71.83%
# Batch number: (147 / 203.5). Progress: 72.32%
# Batch number: (148 / 203.5). Progress: 72.81%
# Batch number: (149 / 203.5). Progress: 73.30%
# Batch number: (150 / 203.5). Progress: 73.79%
# Batch number: (151 / 203.5). Progress: 74.28%
# Batch number: (152 / 203.5). Progress: 74.77%
# Batch number: (153 / 203.5). Progress: 75.27%
# Batch number: (154 / 203.5). Progress: 75.76%
# Batch number: (155 / 203.5). Progress: 76.25%
# Batch number: (156 / 203.5). Progress: 76.74%
# Batch number: (157 / 203.5). Progress: 77.23%
# Batch number: (158 / 203.5). Progress: 77.72%
# Batch number: (159 / 203.5). Progress: 78.21%
# Batch number: (160 / 203.5). Progress: 78.71%
# Batch number: (161 / 203.5). Progress: 79.20%
# Batch number: (162 / 203.5). Progress: 79.69%
# Batch number: (163 / 203.5). Progress: 80.18%
# Batch number: (164 / 203.5). Progress: 80.67%
# Batch number: (165 / 203.5). Progress: 81.16%
# Batch number: (166 / 203.5). Progress: 81.65%
# Batch number: (167 / 203.5). Progress: 82.15%
# Batch number: (168 / 203.5). Progress: 82.64%
# Batch number: (169 / 203.5). Progress: 83.13%
# Batch number: (170 / 203.5). Progress: 83.62%
# Batch number: (171 / 203.5). Progress: 84.11%
# Batch number: (172 / 203.5). Progress: 84.60%
# Batch number: (173 / 203.5). Progress: 85.09%
# Batch number: (174 / 203.5). Progress: 85.59%
# Batch number: (175 / 203.5). Progress: 86.08%
# Batch number: (176 / 203.5). Progress: 86.57%
# Batch number: (177 / 203.5). Progress: 87.06%
# Batch number: (178 / 203.5). Progress: 87.55%
# Batch number: (179 / 203.5). Progress: 88.04%
# Batch number: (180 / 203.5). Progress: 88.53%
# Batch number: (181 / 203.5). Progress: 89.03%
# Batch number: (182 / 203.5). Progress: 89.52%
# Batch number: (183 / 203.5). Progress: 90.01%
# Batch number: (184 / 203.5). Progress: 90.50%
# Batch number: (185 / 203.5). Progress: 90.99%
# Batch number: (186 / 203.5). Progress: 91.48%
# Batch number: (187 / 203.5). Progress: 91.97%
# Batch number: (188 / 203.5). Progress: 92.47%
# Batch number: (189 / 203.5). Progress: 92.96%
# Batch number: (190 / 203.5). Progress: 93.45%
# Batch number: (191 / 203.5). Progress: 93.94%
# Batch number: (192 / 203.5). Progress: 94.43%
# Batch number: (193 / 203.5). Progress: 94.92%
# Batch number: (194 / 203.5). Progress: 95.41%
# Batch number: (195 / 203.5). Progress: 95.90%
# Batch number: (196 / 203.5). Progress: 96.40%
# Batch number: (197 / 203.5). Progress: 96.89%
# Batch number: (198 / 203.5). Progress: 97.38%
# Batch number: (199 / 203.5). Progress: 97.87%
# Batch number: (200 / 203.5). Progress: 98.36%
# Batch number: (201 / 203.5). Progress: 98.85%
# Batch number: (202 / 203.5). Progress: 99.34%
# Batch number: (203 / 203.5). Progress: 99.84%

# %%
len(predictions)
# Out:
# 1221

# %%
import pickle

model_name_mod = model_name.split("/")[1]
output_path = f"/content/drive/MyDrive/DATS 5980/val_predictions_csqa_knowledge_augment_mcq_{model_name_mod}.pkl"

with open(output_path, 'wb') as fp:
    pickle.dump(predictions, fp)

print(f"Predictions saved to {output_path}")
# Out:
# Predictions saved to /content/drive/MyDrive/DATS 5980/val_predictions_csqa_knowledge_augment_mcq_SmolVLM-Instruct.pkl

# %%
predictions[0]
# Out:
# ({'id': '1afa02df02c908a558b4036e80242fac',
#   'question': 'A revolving door is convenient for two direction travel, but it also serves as a security measure at a what?',
#   'question_concept': 'revolving door',
#   'choices': {'label': ['A', 'B', 'C', 'D', 'E'],
#    'text': ['bank', 'library', 'department store', 'mall', 'new york']},
#   'answerKey': 'A',
#   'correct_answer': 'bank',
#   'ranked_choices': [('bank', 0.14749882221221924),
#    ('mall', 0.1399820104241371),
#    ('department store', 0.12084722220897674),
#    ('library', 0.061140642315149304),
#    ('new york', 0.0514893963932991)],
#   'debug': {'sim_question_choice': [0.12540851533412933,
#     0.019575992599129677,
#     0.051216669380664825,
#     0.039423618465662,
#     0.035584140568971634],
#    'sim_choice_conceptnet': [0.16222569346427917,
#     0.08885040879249573,
#     0.1672675907611847,
#     0.20702093839645386,
#     0.06209290027618408],
#    'scores': [0.14749882221221924,
#     0.061140642315149304,
#     0.12084722220897674,
#     0.1399820104241371,
#     0.0514893963932991],
#    'cn_relations_for_ranked_choices': {'bank': ['revolving door is AtLocation bank'],
#     'mall': ['revolving door is AtLocation mall'],
#     'department store': ['revolving door is AtLocation department store'],
#     'library': [],
#     'new york': []}}},
#  "User: Question: A revolving door is convenient for two direction travel, but it also serves as a security measure at a what?\nChoices: ['bank', 'library', 'department store', 'mall', 'new york']\n\nThese are the choices ranked using semantic ranker and some of the facts related to it:\nChoice: bank\nrevolving door is AtLocation bank.\nChoice: mall\nrevolving door is AtLocation mall.\nChoice: department store\nrevolving door is AtLocation department store.\n\n\nUse proper reasoning and facts provided.\nGive only the single correct answer. Do not provide any reasoning, explanation, or extra text.\nAnswer (just one choice):\nAssistant: Bank.")

# %%
predictions[1]
# Out:
# ({'id': 'a7ab086045575bb497933726e4e6ad28',
#   'question': 'What do people aim to do at work?',
#   'concept': 'people',
#   'choices': {'label': ['A', 'B', 'C', 'D', 'E'],
#    'text': ['complete job',
#     'learn from each other',
#     'kill animals',
#     'wear hats',
#     'talk to each other']},
#   'answerKey': 'A',
#   'knowledge_context': '\nChoice A: complete job\n  - complete job MotivatedByGoal work  [score=0.436]\n  - complete job CapableOf workman  [score=0.404]\n  - complete job CapableOf people  [score=0.374]\n\nChoice B: learn from each other\n  - people CapableOf learn from each other  [score=0.341]\n  - learn from each other CapableOf people  [score=0.216]\n\nChoice C: kill animals\n  - kill animals CapableOf people  [score=0.230]\n  - kill animals UsedFor bones  [score=0.202]\n  - kill animals RelatedTo hunt  [score=0.188]\n  - kill animals CapableOf poisonous substances  [score=0.118]\n\nChoice D: wear hats\n  - wear hats CapableOf people  [score=0.285]\n  - wear hats CapableOf snowmen  [score=0.193]\n  - wear hats NotCapableOf most monkeys  [score=0.150]\n\nChoice E: talk to each other\n  - people CapableOf talk to each other  [score=0.386]\n  - talk to each other CapableOf people  [score=0.189]\n  - talk to each other HasSubevent having friends over  [score=0.080]'},
#  "User: Question: What do people aim to do at work?\nChoices: ['complete job', 'learn from each other', 'kill animals', 'wear hats', 'talk to each other']\n\nThese are the Relevant facts that will help in finding the right answer (grouped by choice):\n\nChoice A: complete job\n  - complete job MotivatedByGoal work  [score=0.436]\n  - complete job CapableOf workman  [score=0.404]\n  - complete job CapableOf people  [score=0.374]\n\nChoice B: learn from each other\n  - people CapableOf learn from each other  [score=0.341]\n  - learn from each other CapableOf people  [score=0.216]\n\nChoice C: kill animals\n  - kill animals CapableOf people  [score=0.230]\n  - kill animals UsedFor bones  [score=0.202]\n  - kill animals RelatedTo hunt  [score=0.188]\n  - kill animals CapableOf poisonous substances  [score=0.118]\n\nChoice D: wear hats\n  - wear hats CapableOf people  [score=0.285]\n  - wear hats CapableOf snowmen  [score=0.193]\n  - wear hats NotCapableOf most monkeys  [score=0.150]\n\nChoice E: talk to each other\n  - people CapableOf talk to each other  [score=0.386]\n  - talk to each other CapableOf people  [score=0.189]\n  - talk to each other HasSubevent having friends over  [score=0.080]\n\nEnsure that all the aspects of the question are considered from the relavant facts and choices.\nGive only the single correct answer. Do not include any reasoning, explanation, or extra text.\nAnswer (just one choice):\nAssistant: Answer: learn from each other")

# %%
batch_size = 4
predictions = []
dataset = test_aokvqa_dataset[: 150]
# dataset = test_aokvqa_dataset[:2400]
# dataset = test_aokvqa_dataset[2400: 3600]
# dataset = test_aokvqa_dataset[3600: 5000]
# dataset = test_aokvqa_dataset[5000:]

print(f"dataset size: {len(dataset)}")

predictions = run_batch_predictions(dataset, batch_size, coco_filtered_dir, 'test')
# Out:
# dataset size: 6702
# Batch number: 0. Progress: 0.67%
# Batch number: 1. Progress: 3.33%
# Batch number: 2. Progress: 6.00%
# Batch number: 3. Progress: 8.67%
# Batch number: 4. Progress: 11.33%
# Batch number: 5. Progress: 14.00%
# Batch number: 6. Progress: 16.67%
# Batch number: 7. Progress: 19.33%
# Batch number: 8. Progress: 22.00%
# Batch number: 9. Progress: 24.67%
# Batch number: 10. Progress: 27.33%
# Batch number: 11. Progress: 30.00%
# Batch number: 12. Progress: 32.67%
# Batch number: 13. Progress: 35.33%
# Batch number: 14. Progress: 38.00%
# Batch number: 15. Progress: 40.67%
# Batch number: 16. Progress: 43.33%
# Batch number: 17. Progress: 46.00%
# Batch number: 18. Progress: 48.67%
# Batch number: 19. Progress: 51.33%
# Batch number: 20. Progress: 54.00%
# Batch number: 21. Progress: 56.67%
# Batch number: 22. Progress: 59.33%
# Batch number: 23. Progress: 62.00%
# Batch number: 24. Progress: 64.67%
# Batch number: 25. Progress: 67.33%
# Batch number: 26. Progress: 70.00%
# Batch number: 27. Progress: 72.67%
# Batch number: 28. Progress: 75.33%
# Batch number: 29. Progress: 78.00%
# Batch number: 30. Progress: 80.67%
# Batch number: 31. Progress: 83.33%
# Batch number: 32. Progress: 86.00%
# Batch number: 33. Progress: 88.67%
# Batch number: 34. Progress: 91.33%
# Batch number: 35. Progress: 94.00%
# Batch number: 36. Progress: 96.67%
# Batch number: 37. Progress: 99.33%

# %%
len(predictions)
# Out:
# 150

# %%
import pickle

output_path = '/content/drive/MyDrive/DATS 5980/test_predictions_mcq.pkl'
with open(output_path, 'wb') as fp:
    pickle.dump(predictions, fp)

print(f"Predictions saved to {output_path}")
# Out:
# Predictions saved to /content/drive/MyDrive/DATS 5980/test_predictions_mcq.pkl

# %%
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Wed Sep 17 09:51:48 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   59C    P0             27W /   70W |    3278MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+
